# %%
import requests
from bs4 import BeautifulSoup as bs

LOGIN_INFO = {
    'userId': 'myidid',
    'userPassword': 'mypassword123'
}

with requests.Session() as s:
    first_page = s.get('https://www.clien.net/service')
    html = first_page.text
    soup = bs(html, 'html.parser')
    csrf = soup.find('input', {'name': '_csrf'}) 
    print(csrf['value']) 

    LOGIN_INFO = {**LOGIN_INFO, **{'_csrf': csrf['value']}}
    print(LOGIN_INFO)

    login_req = s.post('https://www.clien.net/service/login', data=LOGIN_INFO)
    print(login_req.status_code)
# Out:
# 4e2dfc04-844a-4a60-bccf-345305fa176b
# {'userId': 'myidid', 'userPassword': 'mypassword123', '_csrf': '4e2dfc04-844a-4a60-bccf-345305fa176b'}
# 200

# %%
## parser.py
import requests

## HTTP GET Request
req = requests.get('https://beomi.github.io/beomi.github.io_old/')

## HTML 소스 가져오기
html = req.text
## HTTP Header 가져오기
header = req.headers
## HTTP Status 가져오기 (200: 정상)
status = req.status_code
## HTTP가 정상적으로 되었는지 (True/False)
is_ok = req.ok

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('https://beomi.github.io/beomi.github.io_old/')
html = req.text
soup = BeautifulSoup(html, 'html.parser')

my_titles = soup.select(
    'h3 > a'
    )

for title in my_titles:
    print(title.text)
    print(title.get('href'))
# Out:
# 나만의 웹 크롤러 만들기(4): Django로 크롤링한 데이터 저장하기
# /beomi.github.io_old/python/2017/02/28/HowToMakeWebCrawler-Save-with-Django.html
# 나만의 웹 크롤러 만들기(3): Selenium으로 무적 크롤러 만들기
# /beomi.github.io_old/python/2017/02/27/HowToMakeWebCrawler-With-Selenium.html
# Django에 Social Login 붙이기: Django세팅부터 Facebook/Google 개발 설정까지
# /beomi.github.io_old/python/2017/02/08/Setup-SocialAuth-for-Django.html
# Django에 Custom인증 붙이기
# /beomi.github.io_old/python/2017/02/01/Django-CustomAuth.html
# 나만의 웹 크롤러 만들기(2): Login with Session
# /beomi.github.io_old/python/2017/01/20/HowToMakeWebCrawler-With-Login.html
# 나만의 웹 크롤러 만들기 with Requests/BeautifulSoup
# /beomi.github.io_old/python/2017/01/19/HowToMakeWebCrawler.html
# Celery로 TelegramBot 알림 보내기
# /beomi.github.io_old/2016/12/27/TelegramBot-with-Celery.html
# Virtualenv/VirtualenvWrapper OS별 설치&이용법
# /beomi.github.io_old/2016/12/27/HowToSetup-Virtualenv-VirtualenvWrapper.html
# [DjangoTDDStudy] #02: UnitTest 이용해 기능 테스트 하기
# /beomi.github.io_old/djangotddstudy/2016/12/26/Django-TDD-Study-02-Using-UnitTest.html
# [DjangoTDDStudy] #01: 개발환경 세팅하기(Selenium / ChromeDriver)
# /beomi.github.io_old/djangotddstudy/2016/12/26/Django-TDD-Study-01-Setting-DevEnviron.html
# [DjangoTDDStudy] #00: 스터디를 시작하며
# /beomi.github.io_old/djangotddstudy/2016/12/26/Django-TDD-Study-00-Starting-Study.html
# Fabric Put 커맨드가 No Such File Exception을 반환할 때 해결법
# /beomi.github.io_old/2016/12/21/Fabric-Put-Command-No-Such-File-Exception.html
# CKEditor의 라이센스와 오픈소스 라이센스
# /beomi.github.io_old/2016/12/21/CKEditor-Lisence-and-Pricing.html
# ReactNative The Basis 번역을 끝냈습니다.
# /beomi.github.io_old/translation/2016/12/20/ReactNative-Translation-Intro-Finish.html
# [React Native 번역]#01: 시작하기
# /beomi.github.io_old/translation/2016/11/15/ReactNative-Translation-01-getting-started.html
# [번역] 장고(Django)와 함께하는 Celery 첫걸음
# /beomi.github.io_old/django-celery/programming/python/translation/2016/11/04/eb-b2-88-ec-97-ad-ec-9e-a5-ea-b3-a0django-ec-99-80-ed-95-a8-ea-bb-98-ed-95-98-eb-8a-94-celery-ec-b2-ab-ea-b1-b8-ec-9d-8c.html
# Chrome Native Adblockr 대체하기
# /beomi.github.io_old/tech/2016/09/14/chrome-native-adblockr-eb-8c-80-ec-b2-b4-ed-95-98-ea-b8-b0.html
# CustoMac 설치 분투기
# /beomi.github.io_old/dev%20env%20setup/mac%20/%20os%20x/tech/2016/08/09/customac-ec-84-a4-ec-b9-98-eb-b6-84-ed-88-ac-ea-b8-b0.html
# Ubuntu14.04에 OhMyZsh 설치
# /beomi.github.io_old/dev%20env%20setup/tech/ubuntu%20/%20debian/2016/07/22/ubuntu14-04-ec-97-90-ohmyzsh-ec-84-a4-ec-b9-98.html
# Ubuntu14.04에서 pip로 mysqlclient 설치 실패시
# /beomi.github.io_old/programming/python/tech/2016/07/22/ubuntu14-04-ec-97-90-ec-84-9c-pip-eb-a1-9c-mysqlclient-ec-84-a4-ec-b9-98-ec-8b-a4-ed-8c-a8-ec-8b-9c.html
# Ubuntu14.04에서 Python3기반 virtualenvwrapper 설치
# /beomi.github.io_old/mac%20/%20os%20x/programming/python/tech/2016/07/22/ubuntu14-04-ec-97-90-ec-84-9c-python3-ea-b8-b0-eb-b0-98-virtualenvwrapper-ec-84-a4-ec-b9-98.html
# mac OS X에서 pip virtualenvwrapper 설치 시 uninstalling six 에서 Exception 발생 시
# /beomi.github.io_old/mac%20/%20os%20x/programming/python/tech/2016/07/21/mac-os-x-ec-97-90-ec-84-9c-pip-virtualenvwrapper-ec-84-a4-ec-b9-98-ec-8b-9c-uninstalling-six-ec-97-90-ec-84-9c-exception-eb-b0-9c-ec-83-9d-ec-8b-9c.html
# Fabric for Python3 (Fabric3)
# /beomi.github.io_old/programming/python/2016/07/17/fabric-for-python3-fabric3.html
# Windows에서 pip로 mysqlclient 설치 실패시(python3.4/3.5)
# /beomi.github.io_old/programming/python/2016/06/04/windows-ec-97-90-ec-84-9c-pip-eb-a1-9c-mysqlclient-ec-84-a4-ec-b9-98-ec-8b-a4-ed-8c-a8-ec-8b-9cpython3-43-5.html
# 맥에서 윈도RDP로 접속시 한영전환하기.
# /beomi.github.io_old/mac%20/%20os%20x/tech/2016/05/27/eb-a7-a5-ec-97-90-ec-84-9c-ec-9c-88-eb-8f-84rdp-eb-a1-9c-ec-a0-91-ec-86-8d-ec-8b-9c-ed-95-9c-ec-98-81-ec-a0-84-ed-99-98-ed-95-98-ea-b8-b0.html
# pip로 mysqlclient설치 중 mac os x에서 egg_info / OSError 발생시 대처방법
# /beomi.github.io_old/programming/python/2016/05/27/pip-eb-a1-9c-mysqlclient-ec-84-a4-ec-b9-98-ec-a4-91-mac-os-x-ec-97-90-ec-84-9c-egg_info-oserror-eb-b0-9c-ec-83-9d-ec-8b-9c-eb-8c-80-ec-b2-98-eb-b0-a9-eb-b2-95.html

# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/nusys/Downloads/chromedriver_mac64/chromedriver')
driver.implicitly_wait(3)

driver.get('https://google.com')

# %%
from selenium import webdriver

driver = webdriver.Chrome('chromedriver')

driver.get('http://naver.com')
driver.implicitly_wait(3)
driver.get_screenshot_as_file('naver_main.png')

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chromedriver': 'chromedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-50-4ab41b07be03> in <module>
#       1 from selenium import webdriver
#       2
# ----> 3 driver = webdriver.Chrome('chromedriver')
#       4
#       5 driver.get('http://naver.com')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/nusys/Downloads/chromedriver_mac64/chromedriver')
driver.implicitly_wait(3)

driver.get('https://nid.naver.com/nidlogin.login')

driver.find_element_by_name('id').send_keys('34547arf')
driver.find_element_by_name('pw').send_keys('rudfhr7177')

driver.find_element_by_xpath('//*[@id="frmNIDLogin"]/fieldset/input').click()

# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/nusys/Downloads/chromedriver_mac64/chromedriver')
driver.implicitly_wait(3)

driver.get('https://nid.naver.com/nidlogin.login')

driver.find_element_by_name('id').send_keys('34547arf')
driver.find_element_by_name('pw').send_keys('rudfhr7177')

driver.find_element_by_xpath('//*[@id="frmNIDLogin"]/fieldset/input').click()

driver.get('https://order.pay.naver.com/home')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
notices = soup.select('div.p_inr > div.p_info > a > span')

for n in notices:
    print(n.text.strip())

# %%
from django.db import models


class BlogData(models.Model):
    title = models.CharField(max_length=200)
    link = models.URLField()
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-48-ba2f3f0d4e16> in <module>
#       2
#       3
# ----> 4 class BlogData(models.Model):
#       5     title = models.CharField(max_length=200)
#       6     link = models.URLField()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/django/db/models/base.py in __new__(cls, name, bases, attrs, **kwargs)
#     105
#     106         # Look for an application configuration to attach the model to.
# --> 107         app_config = apps.get_containing_app_config(module)
#     108
#     109         if getattr(meta, 'app_label', None) is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/django/apps/registry.py in get_containing_app_config(self, object_name)
#     250         Return None if the object isn't in any registered app config.
#     251         """
# --> 252         self.check_apps_ready()
#     253         candidates = []
#     254         for app_config in self.app_configs.values():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/django/apps/registry.py in check_apps_ready(self)
#     132             # INSTALLED_APPS raises a more helpful ImproperlyConfigured
#     133             # exception.
# --> 134             settings.INSTALLED_APPS
#     135             raise AppRegistryNotReady("Apps aren't loaded yet.")
#     136
#
# ~/opt/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py in __getattr__(self, name)
#      74         """Return the value of a setting and cache it in self.__dict__."""
#      75         if self._wrapped is empty:
# ---> 76             self._setup(name)
#      77         val = getattr(self._wrapped, name)
#      78         self.__dict__[name] = val
#
# ~/opt/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py in _setup(self, name)
#      59                 "You must either define the environment variable %s "
#      60                 "or call settings.configure() before accessing settings."
# ---> 61                 % (desc, ENVIRONMENT_VARIABLE))
#      62
#      63         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting INSTALLED_APPS, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
import telegram  

my_token = '1118537264:AAHIv8FE5tdM-wH4PSYqeAT_mspvyaULcVU'   

bot = telegram.Bot(token = my_token)   

updates = bot.getUpdates()  

for u in updates :  

print(u.message)
# Out:
#   File "<ipython-input-81-949223072657>", line 11
#     print(u.message)
#         ^
# IndentationError: expected an indented block

# %%
import requests
from bs4 import BeautifulSoup
import os

BASE_DIR = os.path.dirname(os.path.abspath(__file__))

req = requests.get('https://news.naver.com/')
req.encoding = 'utf-8'

html = req.text
soup = BeautifulSoup(html, 'html.parser')
posts = soup.select('td.post_subject')
latest = posts[1].text

with open(os.path.join(BASE_DIR, 'latest.txt'), 'r+') as f_read:
    before = f_read.readline()
    if before != latest:

    f_read.close()

with open(os.path.join(BASE_DIR, 'latest.txt'), 'w+') as f_write:
    f_write.write(latest)
    f_write.close()
# Out:
#   File "<ipython-input-77-9c229a12eb2c>", line 19
#     f_read.close()
#          ^
# IndentationError: expected an indented block

# %%
import urllib.request
import bs4

url = "https://news.nate.com/section?mid=n0300"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"id": "newsContents"})
lis = div.findAll("ul", {"class": "mduList1"})

for li in lis:
    print(li.text)
# Out:
# '라임 의혹' 김회장, 알고보니…회삿돈 3억 횡령 실형 전력
# 뉴시스
#
#
# "이종필 라임 前부사장 잠적 전 '靑에 해결책 전달' 말해"
# 중앙일보
#
#
# 금감원, 4월초 라임 사태 현장조사…코로나에 한달 지연
# 연합뉴스
#
#
# 라임사태 키운 '규제 완화'…알고 풀었나 실수였나
# 국민일보
#
#
#  라임 전 부사장, '라임 살릴 회장님' 회사 주식 사들였다
# 서울경제
#
#
# 희대의 '금융사기' 라임 사태…커지는 '금감원 책임론'
# 경향신문
#
#
#
#
# 박원순식 vs 이재명식…어떤 재난긴급생활비가 더 효과적일까
# 머니투데이
#
#
# '전 국민 vs 필요한 계층'…재난기본소득 시행 가능성은?
# SBS
#
#
# 지자체서 쏘아올린 재난기본소득…경기도·울주군·기장군 가세
# 연합뉴스
#
#
# 지자체 최고 200만원 지원, 중앙정부도 재난기본소득 줄까
# 중앙일보
#
#
# 재난기본소득? 쟤만 기본소득!
# 머니투데이
#
#
# 당정 "긴급재난지원금 추진…전국민 80% 검토"
# 머니투데이
#
#
#
#
# '널뛰기' 미 다우지수 이번엔 11% 폭등…"87년만의 최대폭 상승"(종합)
# 연합뉴스
#
#
# 빌 게이츠 "美, '코로나 셧다운' 피할 기회 놓쳤다"
# 뉴스1
#
#
# 연준, 헬리콥터가 아니라 전략폭격기급으로 현금 살포
# 뉴스1
#
#
# "흡혈귀 정치" vs "트럼프 도울 비자금"…美 의회서 막힌 2500조짜리 ...
# 헤럴드경제
#
#
# 연준의 '파격'에 부응 못한 美의회…다우 3% 급락(종합)
# 이데일리
#
#
# 미 연준, 무제한 달러 푼다…회사채·개인대출까지 전방위 매입(종합3보)
# 연합뉴스
#
#
#
#
# 코스피, 글로벌 부양정책 기대감에 이틀째 급반등…1700선 턱밑 추격
# 매일경제
#
#
# '개미들 저가매수 준비'…대기자금성격 투자자예탁금 40조 육박
# 연합뉴스
#
#
#  코스피·코스닥, 정부대책 효과에 8% 동반 급등
# 연합뉴스
#
#
#
#
# 사상 처음 석달째 인구 감소, "결혼도 싫고 출산은 더 싫다"
# 파이낸셜뉴스
#
#
# 사상 첫 3개월째 '인구 자연감소'…출생아수 50개월 연속 감소세
# 뉴스1
#
#
# 대구·경북 인구 줄고 서울·경기 늘었다…"대단지 아파트 입주 영향"
# 이데일리
#
#
# '백약이 무효' 뚝뚝 떨어지는 출생아수…1월 2.6만명 역대 최소
# 이데일리
#
#
#
#
# 외식비 김밥·비빔밥·자장면 죄다 올랐다…칼국수 7천원·냉면 9천원
# 아시아경제
#
#
# "이런 때 서민들은 채소도 못먹겠네"…배추 등 채소가격 봄철 내내 강세
# 경향신문
#
#
# 바닥찍던 돼지·닭고기 값 반등…농가 시름덜까
# 머니투데이
#
#
# '라면·생수 사재기' 노린 슈퍼의 가격 꼼수…손소독제는 4배 널뛰기
# 아시아경제
#
#
# 킹크랩뿐 아니다…코로나19에 수산물 가격 줄줄이 하락 예상
# 연합뉴스
#
#
#
#
# 강남 집값 수억씩 급락하는 혼돈의 주택시장…"그래도 매수 기다려라"
# 조선비즈
#
#
# 4∼6월 서울 아파트 9천852가구 입주…작년보다 40% 늘어
# 연합뉴스
#
#
# '코로나19 여파' 4월 수도권 아파트 입주 물량 대폭 감소
# 뉴시스
#
#
# "서울 아파트 임대차 비중, 4년째 전세 증가·월세 감소"
# 연합뉴스
#
#
# 9억초과 서울아파트 거래 61%↓…"추가매입 신중"
# 머니투데이
#
#
#
#
# [단독] 강성부 "조현아가 먼저 연락…조원태 3년 못간다더라"
# 중앙일보
#
#
# 국민연금 한진칼 분쟁 개입…조원태-조현아 누가 유리할까
# 머니투데이
#
#
# 조원태측 11명 對 조현아측 7명
# 조선비즈
#
#
# 조원태 vs 조현아 점입가경…'누나 연합' 지분 추가
# 한국일보
#
#
# 조현아 연합군 "진심 전달하고 싶다" 호소…한진그룹 내부 여론 흔들릴까(종합...
# 뉴시스
#
#
# 조현아 연합 "경영 복귀 안 할 것"…지분 5% 더 늘려
# JTBC
#
#
#
#
# 4월부터 만 55세도 '주택연금' 가입한다
# 뉴스1
#
#
# 주택연금 월 수령액 평균 1.5% 늘어…다음달 3일 신청자부터
# 연합뉴스
#
#
# "집 안물려줘도 괜찮아요" 자식이 더 권하는 주택연금
# 중앙일보
#
#
# 주택연금 가입자 7만명 돌파…100세 이상도 23명
# 연합뉴스
#
#
# 주택연금 신규가입자 7만명 넘어…최고령 수령자 114세
# 뉴스1
#
#
#
#
# 고가·다주택자 보유세 상한까지 뛴다…집값 하락 본격화되나(종합)
# 연합뉴스
#
#
# 강남권 5억 내린 급매물 등장…집값 본격 하락장 시작되나
# 뉴스1
#
#
# "자금조달계획서 안내려 서둘러 계약"…오늘부터는 과태료
# 이데일리
#
#
# 코로나보다 무서운 자금조달계획…부동산 시장 얼어붙나
# 뉴스1
#
#
# "이 돈 어디서 났어요?"…자금조달계획서 오늘부터 의무화
# 뉴시스
#
#
# 오늘부터 부동산 탈법 거래 모니터링 전국이 '사정권'
# 연합뉴스
#
#
#
#
# 비행기 날개 꺾이자 30여년 바친 일터도 '칼바람'
# 이데일리
#
#
# 유통가 직격탄 "10만명 이상 줄일 수도"
# 이데일리
#
#
# "남일 아니다"…제2의 이스타항공 나올까
# 머니S
#
#
#
#
# 혼란스러운 부동산 시장…서울 '집값 하락' 본격화될까
# 아시아경제
#
#
# 코로나發 집값 하락 시작되나…부동산 '조정론' 확산
# 뉴시스
#
#
# 집값은 '광풍'부는데…규제는 '무풍'인 대전
# 아시아경제
#
#
# '수·용·성' 등 10개단지 '콕' 찍은 국토부 "집값담합 160건 내달 발...
# 뉴스1
#
#
#
#
# 코로나쇼크 누른 반도체의 힘…3월1~20일 수출 10% '쑥'(상보)
# 이데일리
#
#
# 3월 수출 10% 늘었지만···조업일수 '日평균'은 또 마이너스
# 서울경제
#
#
# 3월1~20일 수출액 307억달러…전년대비 10.0% 증가
# 이데일리
#
#
#
#
# 집값 내려도 공시가 오른다…"서울 집값은 이미 많이 올라 있는 상태"
# 쿠키뉴스
#
#
# 공시가격, 강남은 고평가·강북은 저평가(?)…현실화율 격차 커
# 연합뉴스
#
#
# "35억짜리 집주인이 보유세 530만원 때문에 집을 팔까요?"
# 뉴스1
#
#
# 9억이상 공시가 21% 올라…반포아파트 보유세 922만→1351만원
# 동아일보
#
#
# 15억원 이상 아파트 공시가 27%↑…강남 3주택자 보유세 '1억원 시대'
# 한국일보
#
#
#
#
# "구직자 34% '취업사기' 경험…급여조건 과장이 최다"
# 연합뉴스
#
#
# 구직자 3명 중 1명 취업사기 경험···"일자리 빌미 사이비 종교 포교도"
# 경향신문
#
#
# "취업적령 마지노선 늦춰진다…남성 33.5세·여성 31.3세"
# 연합뉴스
#
#
# 작년 구직단념자 월평균 53만명…통계작성 후 최다
# 연합뉴스
#
#
# 대졸예정자 24.8%, 졸업 전 취업…작년보다 3.8%P 늘어
# 연합뉴스

# %%
import urllib.request
from bs4 import BeautifulSoup

def get(max_count = 1):
    base_url = "http://10000img.com/" 
    url = "http://10000img.com/ran.php" 
    
    count = 1
    while count < max_count:
        print("--[%d번 째 이미지]--"% count)
        
        html = urllib.request.urlopen(url)
        source = html.read()
        
        soup = BeautifulSoup(source, "html.parser")

        img = soup.find("img")  
        img_src = img.get("src") 
        img_url = base_url + img_src 
        img_name = img_src.replace("/", "") 
        
        urllib.request.urlretrieve(img_url, "./img/" + img_name)

        print("이미지 src:", img_src)
        print("이미지 url:", img_url)
        print("이미지 명:", img_name)
        print("\n")
        count += 1
    else:
        print("크롤링 종료")
get(25)
# Out:
# --[1번 째 이미지]--
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-0646536ee5c9> in <module>
#      29     else:
#      30         print("크롤링 종료")
# ---> 31 get(25)
#      32
#
# <ipython-input-67-0646536ee5c9> in get(max_count)
#      20         img_name = img_src.replace("/", "")
#      21
# ---> 22         urllib.request.urlretrieve(img_url, "./img/" + img_name)
#      23
#      24         print("이미지 src:", img_src)
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     255         # Handle temporary file setup.
#     256         if filename:
# --> 257             tfp = open(filename, 'wb')
#     258         else:
#     259             tfp = tempfile.NamedTemporaryFile(delete=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: './img/rimg3tay53.gif'

# %%
import urllib.request
import bs4

url = "https://news.nate.com/section?mid=n0300"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"id": "newsContents"})
lis = div.findAll("ul", {"class": "mduList1"})

for li in lis:
    print(li.text)
# Out:
# '라임 의혹' 김회장, 알고보니…회삿돈 3억 횡령 실형 전력
# 뉴시스
#
#
# "이종필 라임 前부사장 잠적 전 '靑에 해결책 전달' 말해"
# 중앙일보
#
#
# 금감원, 4월초 라임 사태 현장조사…코로나에 한달 지연
# 연합뉴스
#
#
# 라임사태 키운 '규제 완화'…알고 풀었나 실수였나
# 국민일보
#
#
#  라임 전 부사장, '라임 살릴 회장님' 회사 주식 사들였다
# 서울경제
#
#
# 희대의 '금융사기' 라임 사태…커지는 '금감원 책임론'
# 경향신문
#
#
#
#
# 박원순식 vs 이재명식…어떤 재난긴급생활비가 더 효과적일까
# 머니투데이
#
#
# '전 국민 vs 필요한 계층'…재난기본소득 시행 가능성은?
# SBS
#
#
# 지자체서 쏘아올린 재난기본소득…경기도·울주군·기장군 가세
# 연합뉴스
#
#
# 지자체 최고 200만원 지원, 중앙정부도 재난기본소득 줄까
# 중앙일보
#
#
# 재난기본소득? 쟤만 기본소득!
# 머니투데이
#
#
# 당정 "긴급재난지원금 추진…전국민 80% 검토"
# 머니투데이
#
#
#
#
# '널뛰기' 미 다우지수 이번엔 11% 폭등…"87년만의 최대폭 상승"(종합)
# 연합뉴스
#
#
# 빌 게이츠 "美, '코로나 셧다운' 피할 기회 놓쳤다"
# 뉴스1
#
#
# 연준, 헬리콥터가 아니라 전략폭격기급으로 현금 살포
# 뉴스1
#
#
# "흡혈귀 정치" vs "트럼프 도울 비자금"…美 의회서 막힌 2500조짜리 ...
# 헤럴드경제
#
#
# 연준의 '파격'에 부응 못한 美의회…다우 3% 급락(종합)
# 이데일리
#
#
# 미 연준, 무제한 달러 푼다…회사채·개인대출까지 전방위 매입(종합3보)
# 연합뉴스
#
#
#
#
# 코스피, 글로벌 부양정책 기대감에 이틀째 급반등…1700선 턱밑 추격
# 매일경제
#
#
# '개미들 저가매수 준비'…대기자금성격 투자자예탁금 40조 육박
# 연합뉴스
#
#
#  코스피·코스닥, 정부대책 효과에 8% 동반 급등
# 연합뉴스
#
#
#
#
# 사상 처음 석달째 인구 감소, "결혼도 싫고 출산은 더 싫다"
# 파이낸셜뉴스
#
#
# 사상 첫 3개월째 '인구 자연감소'…출생아수 50개월 연속 감소세
# 뉴스1
#
#
# 대구·경북 인구 줄고 서울·경기 늘었다…"대단지 아파트 입주 영향"
# 이데일리
#
#
# '백약이 무효' 뚝뚝 떨어지는 출생아수…1월 2.6만명 역대 최소
# 이데일리
#
#
#
#
# 외식비 김밥·비빔밥·자장면 죄다 올랐다…칼국수 7천원·냉면 9천원
# 아시아경제
#
#
# "이런 때 서민들은 채소도 못먹겠네"…배추 등 채소가격 봄철 내내 강세
# 경향신문
#
#
# 바닥찍던 돼지·닭고기 값 반등…농가 시름덜까
# 머니투데이
#
#
# '라면·생수 사재기' 노린 슈퍼의 가격 꼼수…손소독제는 4배 널뛰기
# 아시아경제
#
#
# 킹크랩뿐 아니다…코로나19에 수산물 가격 줄줄이 하락 예상
# 연합뉴스
#
#
#
#
# 강남 집값 수억씩 급락하는 혼돈의 주택시장…"그래도 매수 기다려라"
# 조선비즈
#
#
# 4∼6월 서울 아파트 9천852가구 입주…작년보다 40% 늘어
# 연합뉴스
#
#
# '코로나19 여파' 4월 수도권 아파트 입주 물량 대폭 감소
# 뉴시스
#
#
# "서울 아파트 임대차 비중, 4년째 전세 증가·월세 감소"
# 연합뉴스
#
#
# 9억초과 서울아파트 거래 61%↓…"추가매입 신중"
# 머니투데이
#
#
#
#
# [단독] 강성부 "조현아가 먼저 연락…조원태 3년 못간다더라"
# 중앙일보
#
#
# 국민연금 한진칼 분쟁 개입…조원태-조현아 누가 유리할까
# 머니투데이
#
#
# 조원태측 11명 對 조현아측 7명
# 조선비즈
#
#
# 조원태 vs 조현아 점입가경…'누나 연합' 지분 추가
# 한국일보
#
#
# 조현아 연합군 "진심 전달하고 싶다" 호소…한진그룹 내부 여론 흔들릴까(종합...
# 뉴시스
#
#
# 조현아 연합 "경영 복귀 안 할 것"…지분 5% 더 늘려
# JTBC
#
#
#
#
# 4월부터 만 55세도 '주택연금' 가입한다
# 뉴스1
#
#
# 주택연금 월 수령액 평균 1.5% 늘어…다음달 3일 신청자부터
# 연합뉴스
#
#
# "집 안물려줘도 괜찮아요" 자식이 더 권하는 주택연금
# 중앙일보
#
#
# 주택연금 가입자 7만명 돌파…100세 이상도 23명
# 연합뉴스
#
#
# 주택연금 신규가입자 7만명 넘어…최고령 수령자 114세
# 뉴스1
#
#
#
#
# 고가·다주택자 보유세 상한까지 뛴다…집값 하락 본격화되나(종합)
# 연합뉴스
#
#
# 강남권 5억 내린 급매물 등장…집값 본격 하락장 시작되나
# 뉴스1
#
#
# "자금조달계획서 안내려 서둘러 계약"…오늘부터는 과태료
# 이데일리
#
#
# 코로나보다 무서운 자금조달계획…부동산 시장 얼어붙나
# 뉴스1
#
#
# "이 돈 어디서 났어요?"…자금조달계획서 오늘부터 의무화
# 뉴시스
#
#
# 오늘부터 부동산 탈법 거래 모니터링 전국이 '사정권'
# 연합뉴스
#
#
#
#
# 비행기 날개 꺾이자 30여년 바친 일터도 '칼바람'
# 이데일리
#
#
# 유통가 직격탄 "10만명 이상 줄일 수도"
# 이데일리
#
#
# "남일 아니다"…제2의 이스타항공 나올까
# 머니S
#
#
#
#
# 혼란스러운 부동산 시장…서울 '집값 하락' 본격화될까
# 아시아경제
#
#
# 코로나發 집값 하락 시작되나…부동산 '조정론' 확산
# 뉴시스
#
#
# 집값은 '광풍'부는데…규제는 '무풍'인 대전
# 아시아경제
#
#
# '수·용·성' 등 10개단지 '콕' 찍은 국토부 "집값담합 160건 내달 발...
# 뉴스1
#
#
#
#
# 코로나쇼크 누른 반도체의 힘…3월1~20일 수출 10% '쑥'(상보)
# 이데일리
#
#
# 3월 수출 10% 늘었지만···조업일수 '日평균'은 또 마이너스
# 서울경제
#
#
# 3월1~20일 수출액 307억달러…전년대비 10.0% 증가
# 이데일리
#
#
#
#
# 집값 내려도 공시가 오른다…"서울 집값은 이미 많이 올라 있는 상태"
# 쿠키뉴스
#
#
# 공시가격, 강남은 고평가·강북은 저평가(?)…현실화율 격차 커
# 연합뉴스
#
#
# "35억짜리 집주인이 보유세 530만원 때문에 집을 팔까요?"
# 뉴스1
#
#
# 9억이상 공시가 21% 올라…반포아파트 보유세 922만→1351만원
# 동아일보
#
#
# 15억원 이상 아파트 공시가 27%↑…강남 3주택자 보유세 '1억원 시대'
# 한국일보
#
#
#
#
# "구직자 34% '취업사기' 경험…급여조건 과장이 최다"
# 연합뉴스
#
#
# 구직자 3명 중 1명 취업사기 경험···"일자리 빌미 사이비 종교 포교도"
# 경향신문
#
#
# "취업적령 마지노선 늦춰진다…남성 33.5세·여성 31.3세"
# 연합뉴스
#
#
# 작년 구직단념자 월평균 53만명…통계작성 후 최다
# 연합뉴스
#
#
# 대졸예정자 24.8%, 졸업 전 취업…작년보다 3.8%P 늘어
# 연합뉴스

# %%
import urllib.request
from bs4 import BeautifulSoup
 
print('Beginning file download with urllib2...')
 
url = 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=157297'
req = urllib.request.Request(url)
res = urllib.request.urlopen(url).read()
 
soup = BeautifulSoup(res,'html.parser')
soup = soup.find("div",class_="poster")
#img의 경로를 받아온다
imgUrl = soup.find("img")["src"]
 
urllib.request.urlretrieve(imgUrl, soup.find("img")["alt"]+'.jpg')
# Out:
# Beginning file download with urllib2...
# ('마약왕.jpg', <http.client.HTTPMessage at 0x1136cbe50>)

# %%
from bs4 import BeautifulSoup as bs
from pprint import pprint
import requests

html = requests.get('https://search.naver.com/search.naver?query=날씨')
print(html.text)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="날씨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'날씨'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'날씨'의 네이버 통합검색 결과입니다."> <title>날씨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_200102.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_190612.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return func ...
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/sa/190812/css/sa.css">
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head nx_power"><h2>파워링크</h2>
#
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">날씨</strong><em
#                 class="dsc_ncaution_quotation">&rsquo;</em></span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#         <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none"><span class="ico_arr">&nbsp;</span>
#
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704" class="link_help">도움말</a></p>
#           <button type="button" class="bt_ad_clse">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록
#         안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=2tbP_...">
#       <ul class="lst_type">
#         <li class="lst lst1      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=YaK3nqSXTrzJxcC0H02Mm////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000056791190&amp;d=&#39; + urlencode(&#39;http://srs7909.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">날씨 사이언쌤</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=YaK3nqSXTrzJxcC0H02Mm////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000056791190&amp;d=&#39;+urlencode(&#39;http://srs7909.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">srs7909.co.kr</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>날씨</strong>, 교과서, 학년별 단원별 실험, 명품과학기기
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#         <li class="lst lst2     type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=OK75xtDYj3mphZ1eR3+XIf///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000088574035&amp;d=&#39;+urlencode(&#39;https://wt.kmiti.or.kr:8443&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img src="https://searchad-phinf.pstatic.net/MjAyMDAzMTdfMzAg/MDAxNTg0NDA4ODMyNjEw.zrDDR5lTO22SOIseh-gaKdOUATqVUs598QYPRxOB29Qg.AEu-lyjXa3LOzcpUi9CWQ-_RkPgI74_I4fNs91Zpj18g.JPEG/1480168-966264b1-5da5-4d08-929d-71cab3b66887.jpg?type=f120_120" width="60" height="60" alt="링크이미지" class="img_thumb">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=pK5WoIOudnqTFQqxphRCJP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_tit"
#                onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000088574035&amp;d=&#39; + urlencode(&#39;https://wt.kmiti.or.kr:8443&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">기상기후산업 오픈마켓</a>
#
#
#
#             <div class="url_area">
#               <a href="https://adcr.naver.com/adcr?x=pK5WoIOudnqTFQqxphRCJP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000088574035&amp;d=&#39;+urlencode(&#39;https://wt.kmiti.or.kr:8443&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">wt.kmiti.or.kr:8443</a>
#
#             </div>
#
#
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               기상기후기술부터 산업, 특허까지 모든정보와 지원서비스를 한번에 열람하기.
#
#             </p></div>
#
#
#
#           </div>
#         </li>
#       </ul>
#     </div>
#
#
#
#   </div>
#
#
#
#   <script>g_crt+="&bt=15";</script>
# <div class='result_more section' id='nx_result_more'> <div class='section_head'> <h2>검색결과 더보기</h2> </div> <div class='rsltmr_area'> <ul> <li><a onclick="return goOtherCR(this, 'a=nco_x0n*Z.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=nexearch&amp;sm=tab_mre&amp;query=%EB%82%A0%EC%94%A8&amp;mra=Tk9DX1gwTiox'><strong>소프트웨어 정보</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=kin_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://search.naver.com/search.naver?where=kin&query=%EB%82%A0%EC%94%A8&nso=so:r,a:all,p:all&sm=tab_mre'><strong>지식iN</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=caf_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=article&query=%EB%82%A0%EC%94%A8&ie=utf8&sm=tab_mre'><strong>카페</strong><span class='more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=img_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=image&query=%EB%82%A0%EC%94%A8&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&sm=tab_mre'><strong>이미지</strong><span class='more'></span></a></li><li><a target=_blank onclick="return goOtherCR(this, 'a=app_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='https://s.search.naver.com/p/mobileapp/search.naver?where=svc&query=%EB%82%A0%EC%94%A8'><strong>앱정보</strong><span class='site_more'></span></a></li><li><a onclick="return goOtherCR(this, 'a=rea_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='?where=realtime&sm=tab_mre&query=%EB%82%A0%EC%94%A8&ie=utf8'><strong>실시간검색</strong><span class='more'></span></a></li><li><a target=_blank onclick="return goOtherCR(this, 'a=bok_mre.spl&amp;i=00123FD5_0000000000000000000000000&amp;r=1&amp;u='+urlencode(this.href));" href='http://book.naver.com/search/search.nhn?query=%EB%82%A0%EC%94%A8'><strong>책</strong><span class='site_more'></span></a></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> <li><div><span></span></div></li> </ul> </div> </div> <script> nhn = window.nhn || {}; nhn.search = nhn.search || {}; nhn.search.ResultTabToggler = jindo.$Class({ _welWrapper: null, _welUl: null, _nLength: 0, _nWidth: 0, _nItemHeight: 0, _htConfig: {}, $init: function(b) { this._htConfig = this._validate(b); if (!$(this._htConfig.sId)) { return false; } this._welWrapper = jindo.$Element(this._htConfig.sId); this._welUl = jindo.$Element($$.getSingle("ul", this._welWrapper._element)); var a = $$("a", this._welWrapper._element); this._nLength = a.length; this._nItemHeight = jindo.$Element(a[0]).parent().height(); this._switchClass(); this._attachEvent(); }, _validate: function(b) { var c = { nMaxWidth: 795 }; for (var a in b) { if (b[a]) { c[a] = b[a]; } } return c; }, _attachEvent: function() { jindo.$Fn(this._switchClass, this).attach(window, "resize"); }, _getRow: function(c, a) { var b = 1; if (c % a > 0) { b = Math.ceil(c / a); } else { b = c / a; } return b; }, _switchClass: function() { var b = 4, c = 0, a = this._welWrapper.width(); if (a >= this._htConfig.nMaxWidth) { b = 5; this._welWrapper.addClass("result_more2"); } else { this._welWrapper.removeClass("result_more2"); } c = this._getRow(this._nLength, b); this._welUl.css("height", c * this._nItemHeight + "px"); } }); </script> <script type="text/javascript"> (function() { new nhn.search.ResultTabToggler({ sId : 'nx_result_more' }); }()); </script></div><div id="sub_pack" class="sub_pack"><div class="z_aside section _prs_faq"> <div class="section_head"> <h2>네이버 도움말</h2> </div> <div class="helper"> <ul class="list_helper"> <li><em class="helper_category">[생활형서비스]</em><a href="https://help.naver.com/support/contents/contents.help?serviceNo=5843&categoryNo=20188" onClick="return goOtherCR(this, 'a=faq.article&r=1& ...

# %%
def lotto_create():
    import random
    num = input("로또 번호를 몇번 생성하시겠습니까?:")

    for i in range(0, int(num)):
        lotto = random.sample(range(1, 46), 6)
        print (int(num), "회 로또 자동 생성", lotto)

    condition = input("로또 번호 생성을 끝내시겠습니까?")

    if condition == 'Y':
        print("프로그램을 종료합니다")
    elif condition == 'NN':
        lotto = random.sample(range(1, 46), 6)
        print(int(num), "회 로또 자동 생성", lotto)
    else:
        pass
result = num, condition
return result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-6cda317bdd0e> in <module>
#      16     else:
#      17         pass
# ---> 18 result = num, condition
#      19 return result
#
# NameError: name 'num' is not defined

# %%
import requests
import os

url = 'https://api.telegram.org/bot1118537264:AAHIv8FE5tdM-wH4PSYqeAT_mspvyaULcVU/getUpdates'.format(token)
updates = bot.getUpdates()
updates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-29e56fd467b1> in <module>
#       2 import os
#       3
# ----> 4 url = 'https://api.telegram.org/bot1118537264:AAHIv8FE5tdM-wH4PSYqeAT_mspvyaULcVU/getUpdates'.format(token)
#       5 updates = bot.getUpdates()
#       6 updates
#
# NameError: name 'token' is not defined

# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/nusys/Downloads/chromedriver_mac64/chromedriver')
driver.implicitly_wait(3)

# %%
import urllib.request
import bs4

url = "https://news.nate.com/section?mid=n0300"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"id": "newsContents"})
lis = div.findAll("ul", {"class": "mduList1"})

for idx, li in enumerate(lis):
    print(idx, li.text.strip())
# Out:
# 0 "수출용 진단키트 이름, '독도'로 하자"…국민청원 20만 돌파
# 연합뉴스
#
#
# 코로나 진단키트 수출 어디로…"미국·UAE·인도네시아 먼저"
# 한국일보
#
#
# "117개국이 韓 방역물품 요청…진단키트, 해외수요 폭발"
# 뉴스1
#
#
# "한국 진단키트, 세계가 원한다"…美·UAE·인니, 3국 우선공급
# 머니투데이
#
#
# 수출용 진단키트 이름 '독도'로 합시다…청와대 국민청원 20만 돌파
# 뉴스1
# 1 조원태, 56.7대 43.3으로 '조현아연합' 눌러…한진家 '남매의 난' 일...
# 뉴시스
#
#
# 대한항공, 조양호 발목잡은 '3분의 2룰' 정관 바꿨다
# 연합뉴스
#
#
# 한진그룹 '운명의 날' 밝았다…조원태 1승 거둘 듯
# 연합뉴스
#
#
# 한진칼 '운명의 날'…승기 잡은 조원태, 조현아 연합과 표 대결
# 한국경제
#
#
# 국민연금, 한진칼 주총서 조원태 회장 사내이사 선임에 찬성
# 연합뉴스
#
#
# 한진그룹 "조현아 연합이 경영 맡으면 6개월 못견디고 파산"
# 연합뉴스
# 2 '코로나 덫' 노도강·수용성 풍선효과 빠지나
# 한국일보
#
#
# 코로나가 잡은 서울 집값…열흘 만에 2억 곤두박질
# MBN TV
#
#
# 강남4구 아파트 큰 폭 하락…전국 상승폭 0.11%로 줄어
# 국민일보
#
#
# 풍선효과 '노·도·강'도 시들…서울 아파트값 마이너스 진입 임박
# 뉴스1
#
#
# "비싼집 급히 안팔고 물려준다"…서울 아파트 증여 확산
# 머니투데이
# 3 '종부세 아파트'에 세금폭탄…고가 집값 내릴까?
# 매일경제
#
#
# "비싼집 급히 안팔고 물려준다"…서울 아파트 증여 확산
# 머니투데이
#
#
# 보유세 부담 '껑충'…서울 '반전세' 늘어나나?
# 뉴시스
#
#
# 혼란스러운 부동산 시장…서울 '집값 하락' 본격화될까
# 아시아경제
#
#
# 코로나發 집값 하락 시작되나…부동산 '조정론' 확산
# 뉴시스
#
#
# 집값은 '광풍'부는데…규제는 '무풍'인 대전
# 아시아경제
# 4 "코로나19에도 계획대로" 삼성전자 중국 시안 2공장 첫 가동
# 연합뉴스
#
#
# 삼성전자 영국 웹사이트에서 약 150명 개인정보 유출
# 연합뉴스
#
#
# 이상훈 사장, 삼성전자 이사회서 완전히 물러난다(종합)
# 뉴스1
#
#
# 이건희, 삼성전자 작년 배당금 3천538억원…10년간 1조4천억원
# 연합뉴스
#
#
# 삼성전자, 경영성과급 확 줄었다…'연봉의 22~38%'
# 아시아경제
#
#
# 삼성전자, 3년 만에 인텔에 반도체 영업이익 1위 '반납'
# 연합뉴스
# 5 '코로나發 3중고'에 취준생들 "할 수 있는 게 없다"…채용공고·자격증시험·...
# 한국경제
#
#
# "구직자 34% '취업사기' 경험…급여조건 과장이 최다"
# 연합뉴스
#
#
# 구직자 3명 중 1명 취업사기 경험···"일자리 빌미 사이비 종교 포교도"
# 경향신문
#
#
# "취업적령 마지노선 늦춰진다…남성 33.5세·여성 31.3세"
# 연합뉴스
#
#
# 작년 구직단념자 월평균 53만명…통계작성 후 최다
# 연합뉴스
# 6 한은, 첫 '무제한 돈풀기'…기업·개인 경제에 어떤 효과?
# JTBC
#
#
# 한은, 사상 첫 무제한 돈 풀기…한국판 '양적 완화'
# SBS
#
#
# 한은 "금융권에 무제한 자금"…'한국형 양적완화' 처방
# JTBC
#
#
# 금융시장 경색될라…한은 양적완화 돌입
# 연합뉴스
#
#
# '한국판 양적완화'…IMF때도 안 썼던 카드 꺼내 든 韓銀
# 문화일보
# 7 '라임' 전주 김 前회장, 수배중에도 직원급여 등 수백억 빼갔다
# 국민일보
#
#
# '라임 연루' 신한금투 前직원, 자문사 차려 수수료까지 챙겼다
# 머니투데이
#
#
# '라임 사태' 핵심 이종필 前 부사장, 한국 떴다…인터폴 적색수배
# 아시아경제
#
#
# 라임 돈줄 '김회장'의 수원여객 횡령에 감사도 가담 정황
# 연합뉴스
#
#
# 말썽난 라임펀드에 투자한 상장회사 피해 속출
# 이데일리
#
#
# '라임 사태' 신한금투 전 임원 긴급체포…검사 2명 추가 파견
# 연합뉴스
# 8 개인 코스피 주식 10조 순매수…'동학개미운동' 성공할까
# 연합뉴스
#
#
# 코스피, 글로벌 부양정책 기대감에 이틀째 급반등…1700선 턱밑 추격
# 매일경제
#
#
# '개미들 저가매수 준비'…대기자금성격 투자자예탁금 40조 육박
# 연합뉴스
#
#
#  코스피·코스닥, 정부대책 효과에 8% 동반 급등
# 연합뉴스
# 9 파월 "미국, 경기침체 진입한 듯…실탄 안 모자란다"
# 연합뉴스
#
#
# 미 사상최대 부양책 내놨지만…"경기침체 못 피한다"
# 연합뉴스
#
#
# 코로나發 글로벌 실업대란 현실 되나
# 이투데이
#
#
# 미 상원-백악관, 2조달러 '코로나19 대응' 부양책 협상 타결
# 연합뉴스
#
#
# '널뛰기' 미 다우지수 이번엔 11% 폭등…"87년만의 최대폭 상승"(종합)
# 연합뉴스
#
#
# 빌 게이츠 "美, '코로나 셧다운' 피할 기회 놓쳤다"
# 뉴스1
# 10 서울시 재난긴급생활비, 30일부터 신청…'온라인 5부제' 방식
# 뉴시스
#
#
# 민주당 "소득 하위 70%까지 현금성 지원" 집중 검토
# JTBC
#
#
# 부천시장의 "선별지급 바람직" 견해에···경기도 "그럼 부천 빼고" 갑질 논...
# 서울신문
#
#
# 홍남기, 추경이어 재난수당 잇단 소신 발언…현금 지원 선 긋기
# 뉴시스
#
#
# 박원순식 vs 이재명식…어떤 재난긴급생활비가 더 효과적일까
# 머니투데이
#
#
# '전 국민 vs 필요한 계층'…재난기본소득 시행 가능성은?
# SBS
# 11 금융사 외환건전성 부담금 3개월 면제…외화LCR도 70%↓
# 뉴스1
#
#
# '코로나19'에 달러 가뭄…"국내은행, 외화 LCR 규제 70% 하향 조정"
# 머니S
#
#
# 김용범 "3개월간 금융사 외환건전성 부담금 면제…LCR 규제 70%로"
# 머니투데이
#
#
# [속보] 정부 "국고채 PD 비경쟁인수 한도율 확대·인수기간 연장"
# 연합뉴스
#
#
# [속보] 정부 "금융사, 3개월간 외환건전성 부담금 부과 대상서 제외"
# 연합뉴스
# 12 사상 처음 석달째 인구 감소, "결혼도 싫고 출산은 더 싫다"
# 파이낸셜뉴스
#
#
# 사상 첫 3개월째 '인구 자연감소'…출생아수 50개월 연속 감소세
# 뉴스1
#
#
# 대구·경북 인구 줄고 서울·경기 늘었다…"대단지 아파트 입주 영향"
# 이데일리
#
#
# '백약이 무효' 뚝뚝 떨어지는 출생아수…1월 2.6만명 역대 최소
# 이데일리
# 13 외식비 김밥·비빔밥·자장면 죄다 올랐다…칼국수 7천원·냉면 9천원
# 아시아경제
#
#
# "이런 때 서민들은 채소도 못먹겠네"…배추 등 채소가격 봄철 내내 강세
# 경향신문
#
#
# 바닥찍던 돼지·닭고기 값 반등…농가 시름덜까
# 머니투데이
#
#
# '라면·생수 사재기' 노린 슈퍼의 가격 꼼수…손소독제는 4배 널뛰기
# 아시아경제
#
#
# 킹크랩뿐 아니다…코로나19에 수산물 가격 줄줄이 하락 예상
# 연합뉴스
# 14 4월부터 만 55세도 '주택연금' 가입한다
# 뉴스1
#
#
# 주택연금 월 수령액 평균 1.5% 늘어…다음달 3일 신청자부터
# 연합뉴스
#
#
# "집 안물려줘도 괜찮아요" 자식이 더 권하는 주택연금
# 중앙일보
#
#
# 주택연금 가입자 7만명 돌파…100세 이상도 23명
# 연합뉴스
#
#
# 주택연금 신규가입자 7만명 넘어…최고령 수령자 114세
# 뉴스1

# %%
import urllib.request
import bs4

url = "https://news.nate.com/section?mid=n0600"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"class": "clusterType1"})
lis = div.findAll("ul", {"class": "mduList1"})

for idx, a in enumerate(lis):
    print(idx, a.text.strip())
# Out:
# 0 온라인 학습용 노트북으로 리퍼·이월 제품 괜찮나 살펴보니
# IT조선
#
#
# 페이스북, 커플들을 위한 SNS '튠드' 공개
# 블로터
#
#
# 'RIP 갤럭시S7'…업데이트 중단 소식에도 극찬 '눈길'
# IT조선
#
#
# "닌텐도 스위치, 코로나19 여파·신작 인기에 전 세계적 품귀"
# 연합뉴스
#
#
# 유튜브의 맘대로 '화질 저하'가 남긴 것
# 이데일리
#
#
# "내 자식은 꼭 개발자로···" 코로나19에도 개발자 몸값은 천정부지
# 서울경제

# %%
import urllib.request
import bs4

url = "https://www.youtube.com/watch?v=mCt7q7a7lV0"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"id": "content"})
print(div.text.strip())
# Out:
# YouTube Premium
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
# 광⁠고 없⁠는 YouTube⁠를 즐⁠겨⁠보⁠세⁠요
#
#
#
#
#
#
#
#
#         진행 중...
#
#
#
#
#
#
#
#
#
#
# 나중에
#
#
# 1⁠개⁠월 무⁠료⁠체⁠험
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#         "@type": "ListItem",
#         "position": 1,
#         "item": {
#           "@id": "http:\/\/www.youtube.com\/channel\/UCNhofiqfw5nl-NeDJkXtPvw",
#           "name": "빠니보틀 Pani Bottle"
#         }
#       }
#     ]
#   }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 원인 알아보기닫기
#
#
#
# 춘천
#
#
#
#     빠니보틀/근황/공지
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 빠니보틀 Pani Bottle
#
#
#
#
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
#
#
#         빠니보틀 Pani Bottle을(를) 구독 취소할까요?
#
#
#
# 취소
# 구독 취소
#
#
#
#
#
#
#
#
#
#
#         진행 중...
#
#
#
#
#
#
#
#
#
#
#
# 구독구독중구독 취소37.1만
#
#
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         진행 중...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 추가
#
# 이 동영상을 나중에 다시 보려면?
#
#       로그인하여 동영상을 재생목록에 추가하세요.
#
# 로그인
#
#
# 공유
#
#  더보기
#
#
#
# 신고
#
#
# 동영상을 신고하시겠습니까?
#
#
# 부적절한 콘텐츠를 신고하려면 로그인하세요.
#
#
# 로그인
#
#
#
#
#
# 스크립트
#
#
#
# 번역 추가
#
# 조회수 121,156회
#
#
#
#
#
#
#
# 5,674
#
# 동영상이 마음에 드시나요?
#
#       로그인하여 의견을 알려주세요.
#
# 로그인
#
#
#
# 5,675
#
#
# 46
#
# 동영상이 마음에 안 드시나요?
#
#       로그인하여 의견을 알려주세요.
#
# 로그인
#
#
#
# 47
#
#
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
# 스크립트
#
#
#
#
#
#
# 대화형 스크립트를 로드하지 못했습니다.
#
#
#
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
# 동영상을 대여하면 평가할 수 있습니다.
#
#
#
#
#       현재 이 기능을 사용할 수 없습니다. 나중에 다시 시도해 주세요.
#
#
#
#
#
# 게시일: 2020. 4. 3.자가격리 마지막날 올리는 영상입니다사실 공항에서 음성, 춘천시 보건소에서 또 한번 음성이 나와서 안전합니다만걍 백수처럼 놀고 먹을겸 격리했습니다모닝 막걸리 한병 자시고 찍은 영상이라 발음이 조금 어눌하지만 뭐 마신걸 어쩌겠습니까 캬컄4월은 영상을 올리기 힘들 것 같습니다만약 트위치 방송을 켜게 되면 따로 공지하도록 하겠습니다
#
#
#
#       카테고리
#
#
# 인물/블로그
#
#
#
#
#  더보기
# 간략히
#
#
#
#
#
#
# 로드 중...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 자동재생
#
#
# 자동재생을 사용하도록 설정하면 추천 동영상이 자동으로 이어서 재생됩니다.
#
#
#
#
#         다음 동영상
#
#
#
#
#
#
#
#     혼돈과 충격의 카이로 · 피라미드 방문기(Feat. 호객 퇴치법) - 유라시아【91】
#
#
#      - 길이: 13:21
#
# 빠니보틀 Pani Bottle
# 조회수 547,047회
#
#
#
# 13:21
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     이스탄불 음식 일기 - 유라시아【72】
#
#
#      - 길이: 13:26
#
# 빠니보틀 Pani Bottle
# 조회수 575,878회
#
#
#
# 13:26
#
#
#
#
#
#     유라시아 여행 비하인드 영상 모음 두번째
#
#
#      - 길이: 27:31
#
# 빠니보틀 Pani Bottle
# Recommended for you새 동영상
#
#
#
# 27:31
#
#
#
#
#
#     간부식당 치킨을 다 먹어버린 짬찌들의 대처법! 사회에선 급식당번, 군대에선 권력의 배식조👑 | #깜찍한혼종_푸른거탑 | #Diggle
#
#
#      - 길이: 36:54
#
# tvN D ENT
# 조회수 2,700,936회
#
#
#
# 36:54
#
#
#
#
#
#     [마리텔1] 오늘도 채팅창의 수많은 의혹제기 속에서도 실력발휘하시는 백주부 방송
#
#
#      - 길이: 21:07
#
# 옛능 : MBC 옛날 예능 다시보기
# 조회수 965,386회
#
#
#
# 21:07
#
#
#
#
#
#     진돗개에게 갓 태어난 병아리를 소개시키면 하는 행동
#
#
#      - 길이: 12:03
#
# 올리버쌤
# 조회수 638,347회새 동영상
#
#
#
# 12:03
#
#
#
#
#
#     빠니보틀 질문과 답변
#
#
#      - 길이: 1:14:54
#
# 빠니보틀 Pani Bottle
# 조회수 421,726회
#
#
#
# 1:14:54
#
#
#
#
#
#     오분순삭⏱무한도전 집콕에 지친 구독자님들을 위한 5시간순삭 라이브!
#
#
#      - 길이: 5:05:59
#
# 오분순삭
# 조회수 762,482회새 동영상
#
#
#
# 5:05:59
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       믹스 재생목록
#
#
#
#
#
#
#
#
#
# 모두 재생
#
#
#
#
#
#
#
#
# 관련 재생목록 - 빠니보틀 Pani BottleYouTube
#
#
#
#     생각보다 깨끗한 인도 경험하기 (Feat.기차여행)  - 유라시아【32】
#
#
#      - 길이: 10:36
#
# 빠니보틀 Pani Bottle
# 조회수 378,609회
#
#
#
# 10:36
#
#
#
#
#
#     물가 싼 동유럽에서 쇼핑해보기 - 유라시아【96】
#
#
#      - 길이: 12:21
#
# 빠니보틀 Pani Bottle
# 조회수 421,461회
#
#
#
# 12:21
#
#
#
#
#
#     세계에서 가장 추운 마을 오이먀콘 가보기 - 유라시아【116】
#
#
#      - 길이: 13:13
#
# 빠니보틀 Pani Bottle
# 조회수 269,227회
#
#
#
# 13:13
#
#
#
#
#
#     중국에 마스크 퍼줬다고? 유시민이 조목조목 반박해 줌 | 유시민 시점 |정치합시다
#
#
#      - 길이: 32:55
#
# 정치합시다
# Recommended for you새 동영상
#
#
#
# 32:55
#
#
#
#
#
#     베트남에서 중고 오토바이 사기 - 유라시아【3】
#
#
#      - 길이: 9:45
#
# 빠니보틀 Pani Bottle
# 조회수 220,098회
#
#
#
# 9:45
#
#
#
#
#
#     요르단 아랍 음식 체험기 - 유라시아【84】
#
#
#      - 길이: 14:34
#
# 빠니보틀 Pani Bottle
# 조회수 445,262회
#
#
#
# 14:34
#
#
#
#
#
#     예루살렘 셀카 여행기 - 유라시아【80】
#
#
#      - 길이: 10:35
#
# 빠니보틀 Pani Bottle
# 조회수 388,499회
#
#
#
# 10:35
#
#
#
#
#
#     인도 기차 1등칸 vs 중간칸 vs 꼴등칸 타보기 - 유라시아【35】
#
#
#      - 길이: 18:17
#
# 빠니보틀 Pani Bottle
# 조회수 2,053,438회
#
#
#
# 18:17
#
#
#
#
#
#     [생일 특집] 약간 고급진 두바이 여행 - 【上】
#
#
#      - 길이: 8:41
#
# 빠니보틀 Pani Bottle
# 조회수 297,127회
#
#
#
# 8:41
#
#
#
#
#
#     여행중 만난 유럽 친구들 찾아가기 - 유라시아【107】
#
#
#      - 길이: 15:14
#
# 빠니보틀 Pani Bottle
# 조회수 296,037회
#
#
#
# 15:14
#
#
#
#
#
#     인도에서 밥먹으러 돌아다니기 - 유라시아【47】
#
#
#      - 길이: 11:59
#
# 빠니보틀 Pani Bottle
# 조회수 816,855회
#
#
#
# 11:59

# %%
import urllib.request
import bs4

url = "https://news.nate.com/section?mid=n0600"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"id": "cid825312"})
lis = div.findAll("ul", {"class": "mduList1"})

for a in links:
    href = a.attrs['href']
    text = a.string
    print(text,">",href)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-42b94727d4df> in <module>
#       8
#       9 div = bs_obj.find("div", {"id": "cid825312"})
# ---> 10 lis = div.findAll("ul", {"class": "mduList1"})
#      11
#      12 for a in links:
#
# AttributeError: 'NoneType' object has no attribute 'findAll'
